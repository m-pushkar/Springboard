# %% [markdown]
# ### Original dataset link
# `https://www.yelp.com/dataset`

# %%
import os
import json
import gzip
import pandas as pd
from urllib.request import urlopen

# %%
## Download the data

## !wget http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/Grocery_and_Gourmet_Food_5.json.gz

# %%
# Load data

data = []
with gzip.open('Grocery_and_Gourmet_Food_5.json.gz') as f:
    for i in f:
        data.append(json.loads(i.strip()))
        
print(len(data))
# Out:
# 1143860

# %%
# Load data into Pandas dataframe

df = pd.DataFrame.from_dict(data)
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True  11 19, 2014  A1QVBUH9E1V6I8  4639725183
# 1      5.0      True  10 13, 2016  A3GEOILWLK86XM  4639725183
# 2      5.0      True  11 21, 2015  A32RD6L701BIGP  4639725183
# 3      5.0      True  08 12, 2015  A2UY1O1FBGKIE6  4639725183
# 4      5.0      True  05 28, 2015  A3QHVBQYDV7Z6U  4639725183
#
#       reviewerName                                         reviewText  \
# 0   Jamshed Mathur                                No adverse comment.
# 1        itsjustme                          Gift for college student.
# 2  Krystal Clifton  If you like strong tea, this is for you. It mi...
# 3          U. Kane  Love the tea. The flavor is way better than th...
# 4         The Nana  I have searched everywhere until I browsed Ama...
#
#                          summary  unixReviewTime vote style image
# 0                     Five Stars      1416355200  NaN   NaN   NaN
# 1                 Great product.      1476316800  NaN   NaN   NaN
# 2                         Strong      1448064000  NaN   NaN   NaN
# 3                      Great tea      1439337600  NaN   NaN   NaN
# 4  This is the tea I remembered!      1432771200  NaN   NaN   NaN

# %%
len(df.reviewerName.unique())
# Out:
# 101478

# %%
df.isnull().sum()
# Out:
# overall                 0
# verified                0
# reviewTime              0
# reviewerID              0
# asin                    0
# reviewerName          138
# reviewText            390
# summary               219
# unixReviewTime          0
# vote               985658
# style              551774
# image             1134350
# dtype: int64

# %%
df2 = df.fillna({'reviewerName': 1111})                               # Fill empty values
# df3 = df2[~df2.reviewerName.str.match('1111')]        # Filter empty value rows  

if df.isnull().sum().reviewerName == (len(df2) - len(df3)):
    print ('We successfully filtered NA user row')
else:
    print ('Please check the logic')
# Out:
# We successfully filtered NA user row

# %%
len(df3.reviewerName.unique())
# Out:
# 101477

# %%
df2.loc[df2['reviewerName'] == 1111]
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 5399         5.0      True  11 18, 2015  A2TCW7OML05YKB  B00012NHAC
# 13805        5.0      True  08 28, 2015   ACBIWFCXC9H8A  B0001M10LU
# 16079        4.0      True  02 27, 2014  A1GXJW4152V4LJ  B0001LO3FG
# 25211        5.0      True  08 10, 2014  A1F0YUBWGEOQBX  B00061EYPU
# 46797        4.0     False  08 10, 2014  A1F0YUBWGEOQBX  B000CONMBS
# ...          ...       ...          ...             ...         ...
# 1090203      4.0      True  08 16, 2014  A1CSE3HAJ983NJ  B00AF7LCRI
# 1091184      4.0      True   05 4, 2018  A15KXWCBIRE8FU  B00ARH5GCS
# 1108794      5.0      True  08 28, 2015   ACBIWFCXC9H8A  B000WS1KEU
# 1112529      5.0      True  04 30, 2018  A15KXWCBIRE8FU  B00IH28XDE
# 1134507      5.0     False  10 11, 2015  A3GIWIJINP2T8D  B012HDK6WE
#
#         reviewerName                                         reviewText  \
# 5399            1111                                               good
# 13805           1111                                            so good
# 16079           1111  Last year I gave up all carbonated beverages a...
# 25211           1111                                                 :)
# 46797           1111                                                Hmm
# ...              ...                                                ...
# 1090203         1111  Good bussiness n nice products. Not so good ab...
# 1091184         1111        Only out once a year; a pleasure to consume
# 1108794         1111                           very fresh, great taste!
# 1112529         1111  There are rumours that MSG is bad for you, but...
# 1134507         1111  This would be the very first time I ever opted...
#
#                                    summary  unixReviewTime vote  \
# 5399                            Five Stars      1447804800  NaN
# 13805                           Five Stars      1440720000  NaN
# 16079    Excellent caffine free substitute      1393459200   17
# 25211                           Five Stars      1407628800  NaN
# 46797                           Four Stars      1407628800  NaN
# ...                                    ...             ...  ...
# 1090203                              Nice.      1408147200  NaN
# 1091184                                Yum      1525392000  NaN
# 1108794                       great taste!      1440720000  NaN
# 1112529                   Makes Stuff Good      1525046400    2
# 1134507       WOW, Juicy and Tender Steak!      1444521600  NaN
#
#                                                      style  \
# 5399             {'Size:': ' OG, ESSENTIAL GROUND, 15 OZ'}
# 13805                                                  NaN
# 16079    {'Size:': ' 20 Count (Pack of 6)', 'Flavor:': ...
# 25211                                 {'Size:': ' 1 PACK'}
# 46797    {'Size:': ' 1-Ounce Bags (Pack of 24)', 'Flavo...
# ...                                                    ...
# 1090203                                                NaN
# 1091184                                                NaN
# 1108794                                                NaN
# 1112529                                                NaN
# 1134507                                                NaN
#
#                                                      image
# 5399                                                   NaN
# 13805                                                  NaN
# 16079                                                  NaN
# 25211                                                  NaN
# 46797                                                  NaN
# ...                                                    ...
# 1090203                                                NaN
# 1091184                                                NaN
# 1108794                                                NaN
# 1112529                                                NaN
# 1134507  [https://images-na.ssl-images-amazon.com/image...
#
# [138 rows x 12 columns]

# %%
df_filtered = df2.loc[(df2['verified'] == True) & (df2['reviewerName'] != 1111)]

# %%
df_filtered.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True  11 19, 2014  A1QVBUH9E1V6I8  4639725183
# 1      5.0      True  10 13, 2016  A3GEOILWLK86XM  4639725183
# 2      5.0      True  11 21, 2015  A32RD6L701BIGP  4639725183
# 3      5.0      True  08 12, 2015  A2UY1O1FBGKIE6  4639725183
# 4      5.0      True  05 28, 2015  A3QHVBQYDV7Z6U  4639725183
#
#       reviewerName                                         reviewText  \
# 0   Jamshed Mathur                                No adverse comment.
# 1        itsjustme                          Gift for college student.
# 2  Krystal Clifton  If you like strong tea, this is for you. It mi...
# 3          U. Kane  Love the tea. The flavor is way better than th...
# 4         The Nana  I have searched everywhere until I browsed Ama...
#
#                          summary  unixReviewTime vote style image
# 0                     Five Stars      1416355200  NaN   NaN   NaN
# 1                 Great product.      1476316800  NaN   NaN   NaN
# 2                         Strong      1448064000  NaN   NaN   NaN
# 3                      Great tea      1439337600  NaN   NaN   NaN
# 4  This is the tea I remembered!      1432771200  NaN   NaN   NaN

# %%
len(df_filtered)
# Out:
# 993735

# %%
len(df_filtered.asin.unique())
# Out:
# 41087
