# %% [markdown]
# # Keyword search recommender module

# %% [markdown]
# ## Introduction
#
# Keyword search recommender filtering is constructed to provide recommendations with seacrhed keywords.
#
# It consist of two sub-modules:
# 1. Location based keywords such as zip code, longitude, latitude
# 2. Feature based keywords such as cuisine, style, price
#
# ## Implementation Strategy
#
# ### 1 Pre computation
#
# #### 1.1 Distnace calculation
# To calculate distance between recommended restaurant and user location, `the great circle distance calculated assuming a spherical model of the earth` is implemented as it is more accurate and faster in terms of computing power when compared to other methods.
#
# #### 1.2 Adjusted ratings
# Adjusted ratings is calculated to replace restaurant's average star ratings.
#
# The adjusted score uses the mechanism of the damped mean to regulate the extreme cases of having only a few extreme ratings. k controls the strength of the damping effect: the larger k is, the more actual ratings are required to overcome the global mean. In this case, k is set to 30 (50% quantile of the review counts for all businesses), but it can be tuned according to various business considerations.
#
# Adjusted ratings improves original ratings by considering:
# 1. Average ratings of the restaurant
# 2. Number of ratings by users
#
# ### 2 Implementation
#
# #### 2.1 Development
# Restaurants are filtered by all the user's keywords then ranked by user selected ranking critetia. At the end, top n restaurants returned (top n configuarble by user's preference).
#
# #### 2.2 Testing
# Different test cases are implemented to see completeness and computing time.

# %%
import pandas as pd
import numpy as np

# for distance calculations
from geopy.distance import great_circle   
from geopy.geocoders import Nominatim

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1 Pre computation

# %% [markdown]
# #### 1.1 Distance calculation

# %%
business = pd.read_csv('clean_business.csv')
business['postal_code'] = business.postal_code.astype(str)
business.head()
# Out:
#         city attributes.GoodForMeal attributes.Smoking  \
# 0  Champaign                    NaN                NaN
# 1  Charlotte                    NaN                NaN
# 2       Mesa                    NaN                NaN
# 3    Phoenix                    NaN                NaN
# 4  Las Vegas                    NaN                NaN
#
#   attributes.BusinessAcceptsBitcoin                       address  \
# 0                               NaN                404 E Green St
# 1                               NaN      4508 E Independence Blvd
# 2                               NaN                1255 W Main St
# 3                               NaN  4550 East Cactus Rd, #KSFC-4
# 4                               NaN          9595 W Tropicana Ave
#
#   attributes.BYOBCorkage attributes.WheelchairAccessible  \
# 0                    NaN                             NaN
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                             NaN
#
#   attributes.RestaurantsDelivery state attributes.OutdoorSeating  ...  \
# 0                           True    IL                     False  ...
# 1                            NaN    NC                     False  ...
# 2                            NaN    AZ                       NaN  ...
# 3                          False    AZ                     False  ...
# 4                          False    NV                     False  ...
#
#   hours.Tuesday                         attributes.BusinessParking  \
# 0   11:30-14:30                                               None
# 1           NaN  {'garage': False, 'street': False, 'validated'...
# 2       0:0-0:0  {'garage': False, 'street': False, 'validated'...
# 3     10:0-21:0  {'garage': False, 'street': False, 'validated'...
# 4           NaN  {'garage': False, 'street': False, 'validated'...
#
#   hours.Monday attributes.CoatCheck  \
# 0  11:30-14:30                  NaN
# 1          NaN                  NaN
# 2      0:0-0:0                  NaN
# 3    10:0-21:0                  NaN
# 4          NaN                  NaN
#
#                                                hours hours.Friday  \
# 0  {'Monday': '11:30-14:30', 'Tuesday': '11:30-14...  11:30-14:30
# 1                                                NaN          NaN
# 2  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...      0:0-0:0
# 3  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...    10:0-21:0
# 4                                                NaN          NaN
#
#   attributes.BusinessAcceptsCreditCards attributes.RestaurantsTableService  \
# 0                                  True                                NaN
# 1                                  True                                NaN
# 2                                  True                                NaN
# 3                                  True                                NaN
# 4                                  True                                NaN
#
#                       cuisine                    style
# 0  ethnic food,specialty food  food trucks,restaurants
# 1              middle eastern              restaurants
# 2         donuts,coffee & tea   juice bars & smoothies
# 3                    bakeries    fast food,restaurants
# 4                     mexican    restaurants,fast food
#
# [5 rows x 62 columns]

# %%
delhi = (28.644800, 77.216721)
mumbai = (19.076090, 72.877426)

print(great_circle(delhi, mumbai).miles)
# Out:
# 715.5398883895449

# %%
## Get geolocation of a query

geolocator = Nominatim(user_agent="Recommendation")
address = "175 5th Avenue NYC"
location = geolocator.geocode(address)

print(location.address)
print((location.latitude, location.longitude))
# Out:
# Flatiron Building, 175, 5th Avenue, Flatiron District, Manhattan Community Board 5, Manhattan, New York County, New York, 10010, United States
# (40.741059199999995, -73.98964162240998)

# %% [markdown]
# #### 1.2 Adjusted ratings

# %%
# Global mean ratings

mean_global = ((business.stars * business.review_count).sum() / (business.review_count.sum()))
print("Global mean ratings is ", mean_global)
# Out:
# Global mean ratings is  3.7613193324997347

# %%
# check review_count quantile

print(business.review_count.quantile([0.25, 0.5, 0.75]))
# Out:
# 0.25    10.0
# 0.50    30.0
# 0.75    92.0
# Name: review_count, dtype: float64

# %%
# set k = 30 as it is 50% quantile
k = 30

business['stars_adj'] = ((business.review_count * business.stars) + (k * mean_global)) / (business.review_count + k)

# Display changed metrics 

print('\n Rank by original stars:')
print(business[['review_count', 'stars', 'stars_adj']].sort_values('stars', ascending=False).head())

print('\n Rank by adjusted stars:')
print(business[['review_count', 'stars', 'stars_adj']].sort_values('stars_adj', ascending=False).head())
# Out:
#  Rank by original stars:
#        review_count  stars  stars_adj
# 15052             3    5.0   3.873927
# 4334              3    5.0   3.873927
# 28927            22    5.0   4.285377
# 40392             3    5.0   3.873927
# 11821            87    5.0   4.682390
#
#  Rank by adjusted stars:
#        review_count  stars  stars_adj
# 29761          2329    5.0   4.984247
# 2648           1827    5.0   4.979989
# 33734          1107    5.0   4.967317
# 35172           858    5.0   4.958153
# 3590            842    5.0   4.957385

# %% [markdown]
# ### 2 Implementation

# %% [markdown]
# #### 2.1 Development

# %%
class Recommender_Engine:    
    
    def __init__(self, n=5, stars_original=False):
        """
        Instantiate the object. Default setting for ranking would be stars_adj, to rank by original stars set stars_original=True.
        """
        self.n = n                                                     # Number of recommendations
        self.stars_original = stars_original                           # Boolean for ranking method                            
        self.disply_columns = ['name', 'address', 'city','state',\
                               'attributes.RestaurantsPriceRange2',\
                               'review_count','stars','stars_adj',\
                               'cuisine','style']                    # List of columns to be displayed in the results
        
        if self.stars_original:
            score = 'stars'
        else:
            score = 'stars_adj'
            
        self.recommendation = business[business.is_open == 1].sort_values(score, ascending=False)
                                                                      # Filter only open restaurants
            
    def filter_location(self):
        """
        Filter recommendations by user's location. Matching restaurant is the restaurant within the acceptable distance of the location of interest.
        """
        from geopy.geocoders import Nominatim
        from geopy.distance import great_circle
        
        geolocator = Nominatim(user_agent="Recommendation")
        address = [self.city, self.state, self.zipcode]
        address = ",".join([str(i) for i in address if i != None])
        location = geolocator.geocode(address, timeout=10)
        
        # Calculate recommendations distance and append a column
        self.recommendation['distance_recommendations'] = self.recommendation.apply\
        (lambda row: (great_circle((row.latitude, row.longitude), (location.latitude, location.longitude)).miles), axis=1)
        
        self.disply_columns.insert(0, 'distance_recommendations')
        self.recommendation = self.recommendation[self.recommendation.distance_recommendations <= self.distance_max]
        
    def filter_state(self):
        self.recommendation = self.recommendation[self.recommendation.state == self.state]
        
    def filter_price(self):
        self.recommendation = self.recommendation[self.recommendation\
                            ['attributes.RestaurantsPriceRange2'].isin(self.price)]
    
    def filter_cuisine(self):
        
        idx = []
        for i in self.recommendation.index:
            if self.recommendation.loc[i, 'cuisine'] is not np.nan:
                entry = self.recommendation.loc[i, 'cuisine']
                entry = str(entry).split(',')
                if self.cuisine in entry:
                    idx.append(i)
        self.recommendation = self.recommendation.loc[idx]
         
    def filter_style(self):
        
        idx = []
        for i in self.recommendation.index:
            if self.recommendation.loc[i, 'style'] is not np.nan:
                entry = self.recommendation.loc[i, 'style']
                entry = str(entry).split(',')
                if self.style in entry:
                    idx.append(i)
        self.recommendation = self.recommendation.loc[idx]
        
    def display(self):
        
        if len(self.recommendation) == 0:
            print("Sorry, there are no matching recommendations.")
        elif self.n < len(self.recommendation):
            print("Below is the list of the top {} recommended restaurants for you: ".format(self.n))
            print(self.recommendation.iloc[:self.n][self.disply_columns])
        else:
            print("Below is the list of the top {} recommended restaurants for you: ".format(len(self.recommendation)))
            print(self.recommendation.iloc[self.disply_columns]) 
        
    def keyword_filtering(self, catalog=business[business.is_open == 1], price=None,\
                          zipcode=None, city=None, state=None, distance_max=10, cuisine=None, style=None):
        
        
        self.recommendation = catalog                                  # Set restaurant catalog
        self.recommendation['distance__recommendations'] = np.nan      # Reset distance
        self.disply_columns = ['name', 'address', 'city','state',\
                               'attributes.RestaurantsPriceRange2',\
                               'review_count','stars','stars_adj',\
                               'cuisine','style']                    # Reset columns
        
        # Based on keyword search
        self.zipcode = zipcode
        self.city = city
        self.state = state
        self.distance_max = distance_max
        self.cuisine = cuisine
        self.style = style
        self.price = price
        
        # Filter_location
        if (self.zipcode != None) or (self.city != None) or (self.state != None):      
            if (self.zipcode != None) or (self.city != None):
                self.filter_location()
            elif (self.state != None):
                self.filter_state()
            if len(self.recommendation) == 0:
                print("Sorry, there are no matching recommendations.")
                
        # Filter_price
        if self.price != None:
            self.price = [i.strip() for i in price.split(',')]        # Multiple inputs 
            self.filter_price()
            if len(self.recommendation) == 0:
                print("Sorry, there are no matching recommendations.")
             
        # Filter_cuisine
        if self.cuisine != None:
            self.filter_cuisine()
            if len(self.recommendation) == 0:
                print("Sorry, there are no matching recommendations.")
        
        # Filter_style
        if self.style != None:
            self.filter_style()
            if len(self.recommendation) == 0:
                print("Sorry, there are no matching recommendations.")
                
                
        # Sort recommendations by user input for ranking method
        if self.stars_original:
            score = 'stars'
        else:
            score = 'stars_adj'
            
        self.recommendation = self.recommendation.sort_values(score, ascending=False)
        
        # Display recommendations
        self.display()
        
        return self.recommendation

# %% [markdown]
# #### 2.2 Testing

# %%
# %%time

# Instantiate the object
results = Recommender_Engine();

# Test case 1: Display results
print('Test case 1: *****------------*****\n');
results.display();

# Test case 2: Keyword with city
print('Test case 2: *****------------*****\n')
results.keyword_filtering(city='Phoenix');

# Test case 3: Keyword with state
print('Test case 3: *****------------*****\n')
results.keyword_filtering(state='NV');

# Test case 4: Keyword with zipcode
print('Test case 4: *****------------*****\n')
results.keyword_filtering(zipcode='85023');

# Test case 5: Keyword combination of city, state and zipcode
print('Test case 5: *****------------*****\n')
results.keyword_filtering(city='Las Vegas', state='NV', zipcode='89101');

# Test case 6: Keyword with cuisine
print('Test case 6: *****------------*****\n')
results.keyword_filtering(cuisine='mexican');

# Test case 7: Keyword with style
print('Test case 7: *****------------*****\n')
results.keyword_filtering(style='food trucks');

# Test case 8: Keyword combination of cuisine, style
print('Test case 8: *****------------*****\n')
results.keyword_filtering(cuisine='barbeque', style='restaurants');

# Test case 9: Keyword combination of location, cuisine, style
print('Test case 9: *****------------*****\n')
results.keyword_filtering(city='Las Vegas', state='NV', cuisine='mexican', style='restaurants');

# Test case 10: Keyword combination of price range, location, cuisine, style
print('Test case 10: *****------------*****\n')
results.keyword_filtering(price='1,2', city='Las Vegas', state='NV', cuisine='mexican', style='restaurants');
# Out:
# Test case 1: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#                           name                       address       city state  \
# 29761          Little Miss BBQ          4301 E University Dr    Phoenix    AZ
# 2648              Brew Tea Bar  7380 S Rainbow Blvd, Ste 101  Las Vegas    NV
# 33734          Cocina Madrigal                4044 S 16th St    Phoenix    AZ
# 35172  Green Corner Restaurant    1038 W Southern Ave, Ste 1       Mesa    AZ
# 3590            Worth Takeaway                 218 W Main St       Mesa    AZ
#
#       attributes.RestaurantsPriceRange2  review_count  stars  stars_adj  \
# 29761                                 2          2329    5.0   4.984247
# 2648                                  1          1827    5.0   4.979989
# 33734                                 2          1107    5.0   4.967317
# 35172                                 2           858    5.0   4.958153
# 3590                                  2           842    5.0   4.957385
#
#                                                 cuisine  \
# 29761                                          barbeque
# 2648                                bubble tea,desserts
# 33734                                           mexican
# 35172              mediterranean,sandwiches,greek,salad
# 3590   american (traditional),american (new),sandwiches
#
#                                 style
# 29761                     restaurants
# 2648                restaurants,cafes
# 33734                     restaurants
# 35172                     restaurants
# 3590   breakfast & brunch,restaurants
# Test case 2: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#        distance_recommendations                        name  \
# 29761                  5.236230             Little Miss BBQ
# 33734                  3.145436             Cocina Madrigal
# 1515                   9.351031            Simon's Hot Dogs
# 17107                  9.585450               Chula Seafood
# 5105                   0.870596  Kiss Pollos Estilo Sinaloa
#
#                              address        city state  \
# 29761           4301 E University Dr     Phoenix    AZ
# 33734                 4044 S 16th St     Phoenix    AZ
# 1515   4280 Drinkwater Blvd, Ste 200  Scottsdale    AZ
# 17107            8015 E Roosevelt St  Scottsdale    AZ
# 5105                306 W Yavapai St     Phoenix    AZ
#
#       attributes.RestaurantsPriceRange2  review_count  stars  stars_adj  \
# 29761                                 2          2329    5.0   4.984247
# 33734                                 2          1107    5.0   4.967317
# 1515                                  1           457    5.0   4.923695
# 17107                                 2           325    5.0   4.895323
# 5105                                  1           234    5.0   4.859241
#
#                                         cuisine        style
# 29761                                  barbeque  restaurants
# 33734                                   mexican  restaurants
# 1515   latin american,vegetarian,hot dogs,vegan  restaurants
# 17107                    seafood,specialty food  restaurants
# 5105         salad,american (new),mexican,tacos  restaurants
# Test case 3: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#                           name                       address             city  \
# 2648              Brew Tea Bar  7380 S Rainbow Blvd, Ste 101        Las Vegas
# 9839            Zenaida's Cafe  3430 E Tropicana Ave, Ste 32        Las Vegas
# 21628  Bajamar Seafood & Tacos         1615 S Las Vegas Blvd        Las Vegas
# 11825                   Karved          3957 S Maryland Pkwy        Las Vegas
# 37906             Poke Express       655 W Craig Rd, Ste 118  North Las Vegas
#
#       state attributes.RestaurantsPriceRange2  review_count  stars  stars_adj  \
# 2648     NV                                 1          1827    5.0   4.979989
# 9839     NV                                 2           717    5.0   4.950254
# 21628    NV                                 1           658    5.0   4.945988
# 11825    NV                                 2           651    5.0   4.945433
# 37906    NV                                 2           591    5.0   4.940160
#
#                                                  cuisine  \
# 2648                                 bubble tea,desserts
# 9839                                                 NaN
# 21628                              tacos,seafood,mexican
# 11825  sandwiches,salad,american (new),american (trad...
# 37906                hawaiian,specialty food,ethnic food
#
#                                                 style
# 2648                                restaurants,cafes
# 9839             cafes,breakfast & brunch,restaurants
# 21628  fast food,dive bars,bars,nightlife,restaurants
# 11825                           restaurants,fast food
# 37906                                     restaurants
# Test case 4: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#        distance_recommendations                         name  \
# 27218                  9.504056  Frank's New York Style Deli
# 42315                  3.664073        Soup & Sausage Bistro
# 23437                  6.784610              Casa De Falafel
# 24424                  8.924564    UK Pho Vietnamese Cuisine
# 19678                  2.393084                  Saffron JAK
#
#                              address      city state  \
# 27218               2301 W Orange Dr   Phoenix    AZ
# 42315                 13240 N 7th St   Phoenix    AZ
# 23437               6730 W Cactus Rd    Peoria    AZ
# 24424                6228 N 43rd Ave  Glendale    AZ
# 19678  814 E Union Hills Dr, Ste C-6   Phoenix    AZ
#
#       attributes.RestaurantsPriceRange2  review_count  stars  stars_adj  \
# 27218                                 1           214    5.0   4.847703
# 42315                                 2           172    5.0   4.816038
# 23437                                 1           169    5.0   4.813264
# 24424                                 1           154    5.0   4.798041
# 19678                                 1           151    5.0   4.794694
#
#                                                  cuisine  \
# 27218                                 sandwiches,burgers
# 42315                                                NaN
# 23437  vegetarian,mexican,vegan,mediterranean,middle ...
# 24424                              vietnamese,vegan,soup
# 19678                                     bakeries,pizza
#
#                          style
# 27218        restaurants,delis
# 42315              restaurants
# 23437              restaurants
# 24424              restaurants
# 19678  restaurants,food trucks
# Test case 5: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#        distance_recommendations                     name  \
# 2648                   9.404663             Brew Tea Bar
# 9839                   5.264246           Zenaida's Cafe
# 21628                  1.087552  Bajamar Seafood & Tacos
# 11825                  3.511716                   Karved
# 37906                  4.906780             Poke Express
#
#                             address             city state  \
# 2648   7380 S Rainbow Blvd, Ste 101        Las Vegas    NV
# 9839   3430 E Tropicana Ave, Ste 32        Las Vegas    NV
# 21628         1615 S Las Vegas Blvd        Las Vegas    NV
# 11825          3957 S Maryland Pkwy        Las Vegas    NV
# 37906       655 W Craig Rd, Ste 118  North Las Vegas    NV
#
#       attributes.RestaurantsPriceRange2  review_count  stars  stars_adj  \
# 2648                                  1          1827    5.0   4.979989
# 9839                                  2           717    5.0   4.950254
# 21628                                 1           658    5.0   4.945988
# 11825                                 2           651    5.0   4.945433
# 37906                                 2           591    5.0   4.940160
#
#                                                  cuisine  \
# 2648                                 bubble tea,desserts
# 9839                                                 NaN
# 21628                              tacos,seafood,mexican
# 11825  sandwiches,salad,american (new),american (trad...
# 37906                hawaiian,specialty food,ethnic food
#
#                                                 style
# 2648                                restaurants,cafes
# 9839             cafes,breakfast & brunch,restaurants
# 21628  fast food,dive bars,bars,nightlife,restaurants
# 11825                           restaurants,fast food
# 37906                                     restaurants
# Test case 6: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#                                     name                 address       city  \
# 33734                    Cocina Madrigal          4044 S 16th St    Phoenix
# 21628            Bajamar Seafood & Tacos   1615 S Las Vegas Blvd  Las Vegas
# 5105          Kiss Pollos Estilo Sinaloa        306 W Yavapai St    Phoenix
# 5863   La Bamba Mexican Grill Restaurant  12102 W Thunderbird Rd  El Mirage
# 4379                      Pollos LaChuya    2706 E University Dr       Mesa
#
#       state attributes.RestaurantsPriceRange2  review_count  stars  stars_adj  \
# 33734    AZ                                 2          1107    5.0   4.967317
# 21628    NV                                 1           658    5.0   4.945988
# 5105     AZ                                 1           234    5.0   4.859241
# 5863     AZ                                 1           213    5.0   4.847076
# 4379     AZ                                 2           193    5.0   4.833361
#
#                                   cuisine  \
# 33734                             mexican
# 21628               tacos,seafood,mexican
# 5105   salad,american (new),mexican,tacos
# 5863                              mexican
# 4379                        mexican,tacos
#
#                                                 style
# 33734                                     restaurants
# 21628  fast food,dive bars,bars,nightlife,restaurants
# 5105                                      restaurants
# 5863                                      restaurants
# 4379                                      restaurants
# Test case 7: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#                                   name                         address  \
# 37281             The Uprooted Kitchen  3000 E Ray Rd, Bldg 6, Ste 105
# 31020                   Redhawk Coffee                  120 Meyran Ave
# 19678                      Saffron JAK   814 E Union Hills Dr, Ste C-6
# 19692                  King's  Sausage                             NaN
# 41275  Tempura Takeover - Inside Mobil              2371 E Baseline Rd
#
#              city state attributes.RestaurantsPriceRange2  review_count  \
# 37281     Gilbert    AZ                                 2           172
# 31020  Pittsburgh    PA                                 1           151
# 19678     Phoenix    AZ                                 1           151
# 19692  Las  Vegas    NV                                 1           102
# 41275     Gilbert    AZ                                 2            66
#
#        stars  stars_adj                                            cuisine  \
# 37281    5.0   4.816038       specialty food,local flavor,vegan,vegetarian
# 31020    5.0   4.794694                              coffee & tea,desserts
# 19678    5.0   4.794694                                     bakeries,pizza
# 19692    5.0   4.718482                        burgers,sandwiches,hot dogs
# 41275    5.0   4.612912  burgers,seafood,mexican,japanese,asian fusion,...
#
#                                                    style
# 37281             street vendors,restaurants,food trucks
# 31020         food trucks,breakfast & brunch,restaurants
# 19678                            restaurants,food trucks
# 19692                  restaurants,food trucks,fast food
# 41275  street vendors,food trucks,food stands,restaur...
# Test case 8: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#                              name                   address       city state  \
# 29761             Little Miss BBQ      4301 E University Dr    Phoenix    AZ
# 11825                      Karved      3957 S Maryland Pkwy  Las Vegas    NV
# 41201         Caldwell County BBQ       18324 E Nunneley Rd    Gilbert    AZ
# 33546  Lefty-J's Island Favorites  860 E Twain Ave, Ste 102  Las Vegas    NV
# 17010               JL Smokehouse           1712 E Broadway    Phoenix    AZ
#
#       attributes.RestaurantsPriceRange2  review_count  stars  stars_adj  \
# 29761                                 2          2329    5.0   4.984247
# 11825                                 2           651    5.0   4.945433
# 41201                                 2           449    5.0   4.922421
# 33546                                 1           219    5.0   4.850761
# 17010                                 2           146    5.0   4.788861
#
#                                                  cuisine  \
# 29761                                           barbeque
# 11825  sandwiches,salad,american (new),american (trad...
# 41201                                           barbeque
# 33546                                  hawaiian,barbeque
# 17010         sandwiches,american (traditional),barbeque
#
#                        style
# 29761            restaurants
# 11825  restaurants,fast food
# 41201            restaurants
# 33546            restaurants
# 17010            restaurants
# Test case 9: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#        distance_recommendations                                   name  \
# 21628                  1.087552                Bajamar Seafood & Tacos
# 26503                  6.758736                             La Cantine
# 3100                   9.599407                          Carnitas King
# 9063                   3.499963  TRES Cazuelas Artisanal Latin Cuisine
# 21366                  7.011026                       Pollos El Dorado
#
#                                address       city state  \
# 21628            1615 S Las Vegas Blvd  Las Vegas    NV
# 26503       3250 N Tenaya Way, Ste 104  Las Vegas    NV
# 3100                6030 W Windmill Ln  Las Vegas    NV
# 9063   3355 Spring Mountain Rd, Ste 35  Las Vegas    NV
# 21366                 5717 Merrill Ave  Las Vegas    NV
#
#       attributes.RestaurantsPriceRange2  review_count  stars  stars_adj  \
# 21628                                 1           658    5.0   4.945988
# 26503                                 2           122    5.0   4.755524
# 3100                                  1           105    5.0   4.724738
# 9063                                  2            92    5.0   4.695406
# 21366                                 1            74    5.0   4.642688
#
#                                                  cuisine  \
# 21628                              tacos,seafood,mexican
# 26503  coffee & tea,mexican,sandwiches,french,bakerie...
# 3100                                             mexican
# 9063   seafood,latin american,mexican,tapas/small plates
# 21366                     mexican,american (traditional)
#
#                                                 style
# 21628  fast food,dive bars,bars,nightlife,restaurants
# 26503                     fast food,cafes,restaurants
# 3100                                      restaurants
# 9063             bars,wine bars,restaurants,nightlife
# 21366                                     restaurants
# Test case 10: *****------------*****
#
# Below is the list of the top 5 recommended restaurants for you:
#        distance_recommendations                                   name  \
# 21628                  1.087552                Bajamar Seafood & Tacos
# 26503                  6.758736                             La Cantine
# 3100                   9.599407                          Carnitas King
# 9063                   3.499963  TRES Cazuelas Artisanal Latin Cuisine
# 21366                  7.011026                       Pollos El Dorado
#
#                                address       city state  \
# 21628            1615 S Las Vegas Blvd  Las Vegas    NV
# 26503       3250 N Tenaya Way, Ste 104  Las Vegas    NV
# 3100                6030 W Windmill Ln  Las Vegas    NV
# 9063   3355 Spring Mountain Rd, Ste 35  Las Vegas    NV
# 21366                 5717 Merrill Ave  Las Vegas    NV
#
#       attributes.RestaurantsPriceRange2  review_count  stars  stars_adj  \
# 21628                                 1           658    5.0   4.945988
# 26503                                 2           122    5.0   4.755524
# 3100                                  1           105    5.0   4.724738
# 9063                                  2            92    5.0   4.695406
# 21366                                 1            74    5.0   4.642688
#
#                                                  cuisine  \
# 21628                              tacos,seafood,mexican
# 26503  coffee & tea,mexican,sandwiches,french,bakerie...
# 3100                                             mexican
# 9063   seafood,latin american,mexican,tapas/small plates
# 21366                     mexican,american (traditional)
#
#                                                 style
# 21628  fast food,dive bars,bars,nightlife,restaurants
# 26503                     fast food,cafes,restaurants
# 3100                                      restaurants
# 9063             bars,wine bars,restaurants,nightlife
# 21366                                     restaurants
# CPU times: user 7.84 s, sys: 153 ms, total: 7.99 s
# Wall time: 8.45 s
#                   city                             attributes.GoodForMeal  \
# 21628        Las Vegas  {'dessert': None, 'latenight': False, 'lunch':...
# 26503        Las Vegas  {'dessert': False, 'latenight': False, 'lunch'...
# 3100         Las Vegas  {'dessert': False, 'latenight': False, 'lunch'...
# 9063         Las Vegas  {'dessert': False, 'latenight': False, 'lunch'...
# 21366        Las Vegas  {'dessert': False, 'latenight': False, 'lunch'...
# ...                ...                                                ...
# 16968        Las Vegas  {'dessert': False, 'latenight': False, 'lunch'...
# 36137        Las Vegas  {'dessert': False, 'latenight': False, 'lunch'...
# 40482        Las Vegas  {'dessert': False, 'latenight': False, 'lunch'...
# 6894   North Las Vegas  {'dessert': True, 'latenight': False, 'lunch':...
# 36196        Las Vegas  {'dessert': False, 'latenight': False, 'lunch'...
#
#       attributes.Smoking attributes.BusinessAcceptsBitcoin  \
# 21628                NaN                             False
# 26503                NaN                               NaN
# 3100                 NaN                               NaN
# 9063                 NaN                               NaN
# 21366                NaN                               NaN
# ...                  ...                               ...
# 16968                NaN                               NaN
# 36137                NaN                               NaN
# 40482                NaN                               NaN
# 6894                 NaN                               NaN
# 36196                NaN                               NaN
#
#                                address attributes.BYOBCorkage  \
# 21628            1615 S Las Vegas Blvd                    NaN
# 26503       3250 N Tenaya Way, Ste 104                    NaN
# 3100                6030 W Windmill Ln                    NaN
# 9063   3355 Spring Mountain Rd, Ste 35                    NaN
# 21366                 5717 Merrill Ave                    NaN
# ...                                ...                    ...
# 16968            2880 S Las Vegas Blvd                    NaN
# 36137           5757 Wayne Newton Blvd                    NaN
# 40482           5757 Wayne Newton Blvd                    NaN
# 6894               6160 N Decatur Blvd                    NaN
# 36196                9460 W Sahara Ave                    NaN
#
#       attributes.WheelchairAccessible attributes.RestaurantsDelivery state  \
# 21628                            True                          False    NV
# 26503                            True                           True    NV
# 3100                              NaN                          False    NV
# 9063                             True                           True    NV
# 21366                             NaN                           True    NV
# ...                               ...                            ...   ...
# 16968                             NaN                          False    NV
# 36137                             NaN                          False    NV
# 40482                             NaN                          False    NV
# 6894                              NaN                           True    NV
# 36196                             NaN                          False    NV
#
#       attributes.OutdoorSeating  ... attributes.CoatCheck  \
# 21628                     False  ...                  NaN
# 26503                     False  ...                  NaN
# 3100                      False  ...                  NaN
# 9063                       True  ...                  NaN
# 21366                      True  ...                  NaN
# ...                         ...  ...                  ...
# 16968                     False  ...                  NaN
# 36137                     False  ...                  NaN
# 40482                     False  ...                  NaN
# 6894                      False  ...                  NaN
# 36196                     False  ...                  NaN
#
#                                                    hours hours.Friday  \
# 21628  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...    11:0-21:0
# 26503  {'Monday': '0:0-0:0', 'Tuesday': '10:0-18:0', ...    10:0-18:0
# 3100   {'Monday': '0:0-0:0', 'Tuesday': '10:0-15:0', ...    10:0-21:0
# 9063   {'Monday': '0:0-0:0', 'Tuesday': '17:0-22:0', ...    17:0-22:0
# 21366  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...    10:0-20:0
# ...                                                  ...          ...
# 16968  {'Monday': '12:0-22:0', 'Thursday': '12:0-22:0...    12:0-22:0
# 36137                                                NaN          NaN
# 40482  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...     7:0-21:0
# 6894   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...      0:0-0:0
# 36196  {'Monday': '10:0-23:0', 'Tuesday': '10:0-23:0'...    10:0-23:0
#
#       attributes.BusinessAcceptsCreditCards  \
# 21628                                  True
# 26503                                  True
# 3100                                   True
# 9063                                   True
# 21366                                  True
# ...                                     ...
# 16968                                  True
# 36137                                  True
# 40482                                  True
# 6894                                   True
# 36196                                  True
#
#       attributes.RestaurantsTableService  \
# 21628                               True
# 26503                              False
# 3100                               False
# 9063                                True
# 21366                                NaN
# ...                                  ...
# 16968                                NaN
# 36137                              False
# 40482                                NaN
# 6894                               False
# 36196                              False
#
#                                                  cuisine  \
# 21628                              tacos,seafood,mexican
# 26503  coffee & tea,mexican,sandwiches,french,bakerie...
# 3100                                             mexican
# 9063   seafood,latin american,mexican,tapas/small plates
# 21366                     mexican,american (traditional)
# ...                                                  ...
# 16968                     american (traditional),mexican
# 36137                                            mexican
# 40482                                            mexican
# 6894                                             mexican
# 36196                                            mexican
#
#                                                 style stars_adj  \
# 21628  fast food,dive bars,bars,nightlife,restaurants  4.945988
# 26503                     fast food,cafes,restaurants  4.755524
# 3100                                      restaurants  4.724738
# 9063             bars,wine bars,restaurants,nightlife  4.695406
# 21366                                     restaurants  4.642688
# ...                                               ...       ...
# 16968                           fast food,restaurants  2.312660
# 36137                                     restaurants  2.245765
# 40482                                     restaurants  2.096072
# 6894                            restaurants,fast food  2.056062
# 36196                           fast food,restaurants  2.038409
#
#       distance__recommendations distance_recommendations
# 21628                       NaN                 1.087552
# 26503                       NaN                 6.758736
# 3100                        NaN                 9.599407
# 9063                        NaN                 3.499963
# 21366                       NaN                 7.011026
# ...                         ...                      ...
# 16968                       NaN                 2.252226
# 36137                       NaN                 5.833564
# 40482                       NaN                 5.993529
# 6894                        NaN                 7.913717
# 36196                       NaN                 8.607269
#
# [594 rows x 65 columns]

# %% [markdown]
# As observed above, 10 queries took about 9 seconds of time. This comes about 1 second per query which is reasonable computation time
